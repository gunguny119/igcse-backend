# %%
import pandas as pd

# %%
df = pd.read_csv('data/biology_data.csv')
df = df[~df['screenshot_path'].isna()]

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import storage

cred = credentials.Certificate('igcse-predict-c18eb87031fd.json')
firebase_admin.initialize_app(cred, {'storageBucket': 'igcse-predict.appspot.com'})

bucket = storage.bucket()

# %%
import os

def check_missing(images, bucket, years):
    years = map(str, years)
    for filename in images:  # screenshots/year/month/component/q1
        found = False
        for y in years:
            if y in filename:
                found = True
                break
        if not found:
            continue
        if 'component2' in filename:
            real_file = filename + '.png'
            blob = bucket.blob(real_file)
            if not blob.exists():
                print(filename)
                continue
        else:
            i = 1
            while True:
                real_file = f'{filename}_p{i}.png'
                blob = bucket.blob(real_file)
                if not blob.exists():
                    if i == 1:
                        print(filename)
                    break
                i += 1

# %%
# for i in bucket.list_blobs():
#     if '.pdf' in i.id or '.DS_Store' in i.id:
#         i.delete()

# %%
# check marking schemes
for i in [41, 42, 43, 61, 62, 63]:
    check_missing(df[df['component'] == i].ms_path.to_list(), bucket, years=[2019, 2020, 2021])

# %%
# check screenshots
for i in [21, 22, 23, 41, 42, 43, 61, 62, 63]:
    check_missing(df[df['component'] == i].screenshot_path.to_list(), bucket, years=[2019, 2020, 2021])
# Out:
# screenshots/biology/2019/march/component22/q28
# screenshots/biology/2019/march/component22/q29
# screenshots/biology/2019/summer/component22/q29
# screenshots/biology/2019/winter/component22/q28
# screenshots/biology/2019/winter/component22/q29
# screenshots/biology/2020/march/component22/q28
# screenshots/biology/2020/summer/component22/q28
# screenshots/biology/2020/winter/component22/q28
# screenshots/biology/2020/winter/component22/q29
# screenshots/biology/2021/march/component22/q28
# screenshots/biology/2021/summer/component22/q31
# screenshots/biology/2021/summer/component22/q32
# screenshots/biology/2021/summer/component22/q35
# screenshots/biology/2021/summer/component22/q36
# screenshots/biology/2021/summer/component22/q37
# screenshots/biology/2021/summer/component22/q38
# screenshots/biology/2021/summer/component22/q39
# screenshots/biology/2021/summer/component22/q40
# screenshots/biology/2021/winter/component22/q28
# screenshots/biology/2021/winter/component22/q29
# ...

# %%
# screenshots
'screenshots/2016/march/component22/q3'
'screenshots/2016/march/component22/q4'
'screenshots/2016/march/component22/q5'
'screenshots/2016/march/component22/q6'
'screenshots/2016/march/component22/q7'
'screenshots/2016/march/component22/q8'
'screenshots/2016/march/component22/q9'
'screenshots/2016/march/component22/q10'
'screenshots/2016/march/component22/q11'
'screenshots/2016/march/component22/q12'
'screenshots/2016/march/component22/q13'
'screenshots/2016/march/component22/q14'
'screenshots/2016/march/component22/q15'
'screenshots/2016/march/component22/q16'
'screenshots/2016/march/component22/q17'
'screenshots/2016/march/component22/q18'
'screenshots/2016/march/component22/q19'
'screenshots/2016/march/component22/q20'
'screenshots/2016/march/component22/q21'
'screenshots/2016/march/component22/q22'
'screenshots/2016/march/component22/q23'
'screenshots/2016/march/component22/q24'
'screenshots/2016/march/component22/q25'
'screenshots/2016/march/component22/q26'
'screenshots/2016/march/component22/q27'
'screenshots/2016/march/component22/q28'
'screenshots/2016/march/component22/q29'
